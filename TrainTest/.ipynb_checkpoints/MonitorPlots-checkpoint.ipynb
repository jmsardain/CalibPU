# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import os

# %%
os.system("ls -lrt /data/jmsardain/CalibPU/trainings/pu/ckpts/Feb42026/metrics.csv")
# Out:
# -rw-rw-r--. 1 jmsardain users 1893 Feb  4 01:50 /data/jmsardain/CalibPU/trainings/pu/ckpts/Feb42026/metrics.csv
# 0

# %%
df = pd.read_csv('/data/jmsardain/CalibPU/trainings/pu/ckpts/Feb42026/metrics.csv') 
df
# Out:
#       Train_Loss     Val_Loss
# 0   14918.735779  3157.192293
# 1   14461.398797  3112.535675
# 2   14268.050049  3101.640473
# 3   14185.988475  3080.773366
# 4   14112.440695  3061.222310
# 5   14056.776510  3050.263231
# 6   14021.597742  3036.582961
# 7   13994.326875  3027.894941
# 8   13970.398898  3022.049403
# 9   13950.049767  3015.538003
# 10  13932.279923  3011.197342
# 11  13916.372037  3007.953072
# 12  13902.341988  3005.715816
# 13  13889.419411  3001.768789
# 14  13877.840176  3000.173803
# 15  13867.047687  2996.925935
# 16  13856.938241  2994.992619
# 17  13847.515751  2993.604109
# 18  13838.722105  2990.444424
# 19  13830.098021  2988.665502
# 20  13821.998548  2987.419897
# 21  13814.350988  2986.253322
# 22  13806.803749  2984.327964
# 23  13799.873262  2983.081674
# 24  13793.372452  2982.346032
# 25  13787.167448  2980.954205
# 26  13781.275763  2979.452563
# 27  13775.680068  2979.183188
# 28  13770.212158  2977.256248
# 29  13765.039751  2976.821353
# 30  13760.172651  2975.916743
# 31  13755.405019  2974.665563
# 32  13751.049356  2974.927984
# 33  13746.916422  2973.608970
# 34  13742.734554  2972.403328
# 35  13738.733716  2971.490664
# 36  13735.041330  2971.689176
# 37  13731.420844  2969.649130
# 38  13727.763761  2969.591955
# 39  13724.426494  2969.236163
# 40  13721.295341  2967.348127
# 41  13718.306258  2967.657550
# 42  13715.381835  2967.029851
# 43  13712.491889  2967.476108
# 44  13710.025982  2966.839442
# 45  13707.490381  2966.140415
# 46  13705.256020  2965.593887
# 47  13702.891402  2965.009023
# 48  13700.709714  2964.660364
# 49  13698.420448  2964.491266

# %%
plt.plot(df.Train_Loss, label='Train')
plt.plot(df.Val_Loss, label='Train')
plt.yscale('log')

# %%
import glob as glob 
import pandas as pd 
import numpy as np
files  = glob.glob('/data/jmsardain/CalibPU/datasets/pu/train_pu_batch_0.npy')
for ifile in range(1, 200):
    files += glob.glob('/data/jmsardain/CalibPU/datasets/pu/train_pu_batch_'+str(ifile)+'.npy')

# %%
train_dataset = [np.load(f, mmap_mode='r') for f in files]

# %%
columns = ["labels",
                    "eventNumber", "jetCnt",
                    "clusterE",
                    "clusterEta",
                    "cluster_time",
                    "cluster_CENTER_LAMBDA", "cluster_CENTER_MAG", "cluster_ENG_FRAC_EM_INCL",
                    "cluster_FIRST_ENG_DENS", "cluster_LATERAL", "cluster_LONGITUDINAL",
                    "cluster_PTD", "cluster_ISOLATION", "cluster_SECOND_TIME", "cluster_SIGNIFICANCE",
                    "nPrimVtx", "avgMu",
                    "clusterPhi", "diffEta",
                    "zT", "zL", "zRel",
                    "cluster_nCells", "jetRawE",
                  ]

# %%
df = pd.DataFrame(np.concatenate(train_dataset), columns=columns)

# %%
df
# Out:
#           labels  eventNumber  jetCnt  clusterE  clusterEta  cluster_time  \
# 0            0.0   46002642.0     1.0  3.556606    1.510319      5.097156
# 1            1.0   46002642.0     1.0  2.726765    1.452857      1.079794
# 2            0.0   46002642.0     1.0  2.020551    1.791052    -24.850691
# 3            1.0   46002642.0     1.0  1.101165    1.391639      2.217566
# 4            0.0   46002642.0     1.0  0.852218    1.416068     -5.794683
# ...          ...          ...     ...       ...         ...           ...
# 99999995     1.0   26076817.0  6340.0  2.338777   -1.083369      0.000000
# 99999996     1.0   26076817.0  6340.0  1.274749   -0.849760      6.995141
# 99999997     1.0   26076817.0  6340.0  1.223811   -1.011159     -6.025061
# 99999998     1.0   26076817.0  6340.0  1.012458   -0.727414    -14.550533
# 99999999     0.0   26076817.0  6340.0  0.971317   -0.811727      0.000000
#
#           cluster_CENTER_LAMBDA  cluster_CENTER_MAG  cluster_ENG_FRAC_EM_INCL  \
# 0                    235.124908         3903.294189                  0.000000
# 1                    111.482292         3505.745361                  0.599973
# 2                     43.470642         4005.075684                  0.732918
# 3                      6.072798         3199.999023                  0.363719
# 4                    213.984909         3456.114258                  0.791060
# ...                         ...                 ...                       ...
# 99999995              81.413277         2551.042969                  0.446813
# 99999996             173.324417         2241.408447                  1.022851
# 99999997              50.830711         2382.155762                  0.529490
# 99999998             237.813110         2131.889404                  1.040851
# 99999999              16.629570         2036.545898                  0.215714
#
#           cluster_FIRST_ENG_DENS  ...  cluster_SIGNIFICANCE  nPrimVtx  \
# 0                   8.823912e-06  ...              2.494832      17.0
# 1                   1.096617e-06  ...              7.714689      17.0
# 2                   6.497267e-06  ...              3.856187      17.0
# 3                   5.457273e-07  ...              4.235492      17.0
# 4                   5.099652e-07  ...              2.954988      17.0
# ...                          ...  ...                   ...       ...
# 99999995            2.014171e-07  ...              7.424483       9.0
# 99999996            3.170190e-07  ...              3.680480       9.0
# 99999997            3.791055e-07  ...              4.073343       9.0
# 99999998            2.863858e-07  ...              2.920921       9.0
# 99999999            1.755519e-07  ...              3.508768       9.0
#
#               avgMu  clusterPhi   diffEta        zT        zL      zRel  \
# 0         23.500002    1.811098  0.001314  0.289336  0.298834  0.010705
# 1         23.500002    2.002567 -0.056149  0.233624  0.228948  0.011882
# 2         23.500002    2.016598  0.282046  0.126672  0.168460  0.021922
# 3         23.500002    1.616889 -0.117367  0.099629  0.091837  0.011722
# 4         23.500002    2.048300 -0.092937  0.075454  0.071440  0.005493
# ...             ...         ...       ...       ...       ...       ...
# 99999995  18.500000    1.722361 -0.091126  0.011099  0.011915  0.001669
# 99999996  18.500000    1.885347  0.142483  0.007201  0.006530  0.000602
# 99999997  18.500000    2.268898 -0.018916  0.006145  0.006131  0.001433
# 99999998  18.500000    1.828135  0.264829  0.006198  0.005112  0.000996
# 99999999  18.500000    1.841965  0.180516  0.005631  0.004956  0.000639
#
#           cluster_nCells     jetRawE
# 0                    1.0   12.153590
# 1                   14.0   12.153590
# 2                   26.0   12.153590
# 3                   14.0   12.153590
# 4                    8.0   12.153590
# ...                  ...         ...
# 99999995            26.0  195.044739
# 99999996            36.0  195.044739
# 99999997            23.0  195.044739
# 99999998            26.0  195.044739
# 99999999            19.0  195.044739
#
# [100000000 rows x 25 columns]

# %%
signal = df[df['labels']==1] 
pileup = df[df['labels']==0]

# %%
import matplotlib.pyplot as plt
bins = np.linspace(-50, 50, endpoint=1) 
plt.hist(signal.cluster_time.values, bins=bins, label = 'Signal', histtype='step')
plt.hist(pileup.cluster_time.values, bins=bins, label = 'PU', histtype='step')
plt.legend()
plt.yscale('log') 
plt.xlabel('cluster time') 
plt.ylabel('Cluster')
# Out:
# Text(0, 0.5, 'Cluster')
